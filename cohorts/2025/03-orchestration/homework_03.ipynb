# %% [markdown]
# ## Q1

# %%
#q1: Airflow
# !pip install "apache-airflow==2.8.1" \
  --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-2.8.1/constraints-3.9.txt"
# Out:
# Collecting apache-airflow==2.8.1
#   Downloading apache_airflow-2.8.1-py3-none-any.whl.metadata (36 kB)
# Collecting alembic<2.0,>=1.6.3 (from apache-airflow==2.8.1)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting argcomplete>=1.10 (from apache-airflow==2.8.1)
#   Downloading argcomplete-3.2.1-py3-none-any.whl.metadata (16 kB)
# Collecting asgiref (from apache-airflow==2.8.1)
#   Downloading asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting attrs>=22.1.0 (from apache-airflow==2.8.1)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting blinker (from apache-airflow==2.8.1)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting colorlog<5.0,>=4.0.2 (from apache-airflow==2.8.1)
#   Downloading colorlog-4.8.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting configupdater>=3.1.1 (from apache-airflow==2.8.1)
#   Downloading ConfigUpdater-3.2-py2.py3-none-any.whl.metadata (10 kB)
# Collecting connexion<3.0,>=2.10.0 (from connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1)
#   Downloading connexion-2.14.2-py2.py3-none-any.whl.metadata (28 kB)
# Collecting cron-descriptor>=1.2.24 (from apache-airflow==2.8.1)
#   Downloading cron_descriptor-1.4.0.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting croniter>=0.3.17 (from apache-airflow==2.8.1)
#   Downloading croniter-2.0.1-py2.py3-none-any.whl.metadata (24 kB)
# Collecting cryptography>=0.9.3 (from apache-airflow==2.8.1)
#   Downloading cryptography-41.0.7-cp37-abi3-macosx_10_12_universal2.whl.metadata (5.2 kB)
# Collecting deprecated>=1.2.13 (from apache-airflow==2.8.1)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dill>=0.2.2 (from apache-airflow==2.8.1)
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting flask-appbuilder==4.3.10 (from apache-airflow==2.8.1)
#   Downloading Flask_AppBuilder-4.3.10-py3-none-any.whl.metadata (8.9 kB)
# Collecting flask-caching>=1.5.0 (from apache-airflow==2.8.1)
#   Downloading Flask_Caching-2.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-login>=0.6.2 (from apache-airflow==2.8.1)
#   Downloading Flask_Login-0.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting flask-session>=0.4.0 (from apache-airflow==2.8.1)
#   Downloading flask_session-0.5.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting flask-wtf>=0.15 (from apache-airflow==2.8.1)
#   Downloading flask_wtf-1.2.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting flask<2.3,>=2.2 (from apache-airflow==2.8.1)
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting fsspec>=2023.10.0 (from apache-airflow==2.8.1)
#   Downloading fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-re2>=1.0 (from apache-airflow==2.8.1)
#   Downloading google_re2-1.1-6-cp39-cp39-macosx_14_0_arm64.whl.metadata (2.1 kB)
# Collecting gunicorn>=20.1.0 (from apache-airflow==2.8.1)
#   Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting httpx (from apache-airflow==2.8.1)
#   Downloading httpx-0.23.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting itsdangerous>=2.0 (from apache-airflow==2.8.1)
#   Downloading itsdangerous-2.1.2-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jinja2>=3.0.0 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from apache-airflow==2.8.1) (3.1.3)
# Collecting jsonschema>=4.18.0 (from apache-airflow==2.8.1)
#   Downloading jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting lazy-object-proxy (from apache-airflow==2.8.1)
#   Downloading lazy-object-proxy-1.10.0.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting linkify-it-py>=2.0.0 (from apache-airflow==2.8.1)
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting lockfile>=0.12.2 (from apache-airflow==2.8.1)
#   Downloading lockfile-0.12.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.1.0 (from apache-airflow==2.8.1)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting markdown>=3.0 (from apache-airflow==2.8.1)
#   Downloading Markdown-3.5.2-py3-none-any.whl.metadata (7.0 kB)
# Collecting markupsafe>=1.1.1 (from apache-airflow==2.8.1)
#   Downloading MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting marshmallow-oneofschema>=2.0.1 (from apache-airflow==2.8.1)
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting mdit-py-plugins>=0.3.0 (from apache-airflow==2.8.1)
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting opentelemetry-api>=1.15.0 (from apache-airflow==2.8.1)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp (from apache-airflow==2.8.1)
#   Downloading opentelemetry_exporter_otlp-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting packaging>=14.0 (from apache-airflow==2.8.1)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from apache-airflow==2.8.1)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pendulum<4.0,>=2.1.2 (from apache-airflow==2.8.1)
#   Downloading pendulum-3.0.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Collecting pluggy>=1.0 (from apache-airflow==2.8.1)
#   Downloading pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting psutil>=4.2.0 (from apache-airflow==2.8.1)
#   Downloading psutil-5.9.7-cp38-abi3-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting pydantic>=2.3.0 (from apache-airflow==2.8.1)
#   Downloading pydantic-2.5.3-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments>=2.0.1 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from apache-airflow==2.8.1) (2.17.2)
# Collecting pyjwt>=2.0.0 (from apache-airflow==2.8.1)
#   Downloading PyJWT-2.8.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting python-daemon>=3.0.0 (from apache-airflow==2.8.1)
#   Downloading python_daemon-3.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting python-dateutil>=2.3 (from apache-airflow==2.8.1)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting python-nvd3>=0.15.0 (from apache-airflow==2.8.1)
#   Downloading python-nvd3-0.15.0.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-slugify>=5.0 (from apache-airflow==2.8.1)
#   Downloading python_slugify-8.0.1-py2.py3-none-any.whl.metadata (8.2 kB)
# Collecting rfc3339-validator>=0.1.4 (from apache-airflow==2.8.1)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rich-argparse>=1.0.0 (from apache-airflow==2.8.1)
#   Downloading rich_argparse-1.4.0-py3-none-any.whl.metadata (14 kB)
# Collecting rich>=12.4.4 (from apache-airflow==2.8.1)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting setproctitle>=1.1.8 (from apache-airflow==2.8.1)
#   Downloading setproctitle-1.3.3-cp39-cp39-macosx_10_9_universal2.whl.metadata (9.9 kB)
# Collecting sqlalchemy-jsonfield>=1.0 (from apache-airflow==2.8.1)
#   Downloading SQLAlchemy_JSONField-1.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting sqlalchemy<2.0,>=1.4.28 (from apache-airflow==2.8.1)
#   Downloading SQLAlchemy-1.4.51.tar.gz (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 4.2 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
# Collecting tabulate>=0.7.5 (from apache-airflow==2.8.1)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tenacity!=8.2.0,>=6.2.0 (from apache-airflow==2.8.1)
#   Downloading tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting termcolor>=1.1.0 (from apache-airflow==2.8.1)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting unicodecsv>=0.14.1 (from apache-airflow==2.8.1)
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting universal-pathlib>=0.1.4 (from apache-airflow==2.8.1)
#   Downloading universal_pathlib-0.1.4-py3-none-any.whl.metadata (8.9 kB)
# Collecting werkzeug<3,>=2.0 (from apache-airflow==2.8.1)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl.metadata (4.4 kB)
# Collecting apache-airflow-providers-common-io (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_common_io-1.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting apache-airflow-providers-common-sql (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_common_sql-1.10.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting apache-airflow-providers-ftp (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_ftp-3.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting apache-airflow-providers-http (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_http-4.8.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting apache-airflow-providers-imap (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_imap-3.5.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting apache-airflow-providers-sqlite (from apache-airflow==2.8.1)
#   Downloading apache_airflow_providers_sqlite-3.7.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting apispec<7,>=6.0.0 (from apispec[yaml]<7,>=6.0.0->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading apispec-6.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting colorama<1,>=0.3.9 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: click<9,>=8 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from flask-appbuilder==4.3.10->apache-airflow==2.8.1) (8.1.7)
# Collecting email-validator<2,>=1.0.5 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading email_validator-1.3.1-py2.py3-none-any.whl.metadata (23 kB)
# Collecting Flask-Babel<3,>=1 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading Flask_Babel-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting Flask-Limiter<4,>3 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading Flask_Limiter-3.5.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting Flask-SQLAlchemy<3,>=2.4 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting Flask-JWT-Extended<5.0.0,>=4.0.0 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading Flask_JWT_Extended-4.6.0-py2.py3-none-any.whl.metadata (3.9 kB)
# Collecting marshmallow<4,>=3.18.0 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading marshmallow-3.20.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting marshmallow-sqlalchemy<0.27.0,>=0.22.0 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting prison<1.0.0,>=0.2.1 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading prison-0.2.1-py2.py3-none-any.whl.metadata (973 bytes)
# Collecting sqlalchemy-utils<1,>=0.32.21 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading SQLAlchemy_Utils-0.41.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting WTForms<4 (from flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading wtforms-3.1.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting Mako (from alembic<2.0,>=1.6.3->apache-airflow==2.8.1)
#   Downloading Mako-1.3.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4 (from alembic<2.0,>=1.6.3->apache-airflow==2.8.1)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting clickclick<21,>=1.2 (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1)
#   Downloading clickclick-20.10.2-py2.py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: PyYAML<7,>=5.1 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1) (6.0.1)
# Requirement already satisfied: requests<3,>=2.9.1 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1) (2.31.0)
# Collecting inflection<0.6,>=0.3.1 (from connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting pytz>2021.1 (from croniter>=0.3.17->apache-airflow==2.8.1)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting cffi>=1.12 (from cryptography>=0.9.3->apache-airflow==2.8.1)
#   Using cached cffi-1.16.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.13->apache-airflow==2.8.1)
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting importlib-metadata>=3.6.0 (from flask<2.3,>=2.2->apache-airflow==2.8.1)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting cachelib<0.10.0,>=0.9.0 (from flask-caching>=1.5.0->apache-airflow==2.8.1)
#   Downloading cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->apache-airflow==2.8.1)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->apache-airflow==2.8.1)
#   Downloading referencing-0.32.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->apache-airflow==2.8.1)
#   Downloading rpds_py-0.17.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting uc-micro-py (from linkify-it-py>=2.0.0->apache-airflow==2.8.1)
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.1.0->apache-airflow==2.8.1)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting tzdata>=2020.1 (from pendulum<4.0,>=2.1.2->apache-airflow==2.8.1)
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting time-machine>=2.6.0 (from pendulum<4.0,>=2.1.2->apache-airflow==2.8.1)
#   Downloading time_machine-2.13.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (21 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from pydantic>=2.3.0->apache-airflow==2.8.1) (0.6.0)
# Collecting pydantic-core==2.14.6 (from pydantic>=2.3.0->apache-airflow==2.8.1)
#   Downloading pydantic_core-2.14.6-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Collecting docutils (from python-daemon>=3.0.0->apache-airflow==2.8.1)
#   Downloading docutils-0.20.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: setuptools>=62.4.0 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from python-daemon>=3.0.0->apache-airflow==2.8.1) (68.0.0)
# Requirement already satisfied: six>=1.5 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from python-dateutil>=2.3->apache-airflow==2.8.1) (1.16.0)
# Collecting text-unidecode>=1.3 (from python-slugify>=5.0->apache-airflow==2.8.1)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting sqlparse>=0.4.2 (from apache-airflow-providers-common-sql->apache-airflow==2.8.1)
#   Downloading sqlparse-0.4.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting aiohttp (from apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading aiohttp-3.9.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting requests_toolbelt (from apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting certifi (from httpx->apache-airflow==2.8.1)
#   Downloading certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx->apache-airflow==2.8.1)
#   Downloading httpcore-0.16.3-py3-none-any.whl.metadata (16 kB)
# Collecting rfc3986<2,>=1.3 (from rfc3986[idna2008]<2,>=1.3->httpx->apache-airflow==2.8.1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: sniffio in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from httpx->apache-airflow==2.8.1) (1.3.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.22.0 (from opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http==1.22.0 (from opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting grpcio<2.0.0,>=1.0.0 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading grpcio-1.60.0-cp39-cp39-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk~=1.22.0 (from opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting protobuf<5.0,>=3.19 (from opentelemetry-proto==1.22.0->opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading protobuf-4.25.2-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting pycparser (from cffi>=1.12->cryptography>=0.9.3->apache-airflow==2.8.1)
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting dnspython>=1.15.0 (from email-validator<2,>=1.0.5->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Using cached dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting idna>=2.0.0 (from email-validator<2,>=1.0.5->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting Babel>=2.3 (from Flask-Babel<3,>=1->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Using cached Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting limits>=2.8 (from Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading limits-3.7.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: ordered-set<5,>4 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow==2.8.1) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow==2.8.1) (0.14.0)
# Collecting anyio<5.0,>=3.0 (from httpcore<0.17.0,>=0.15.0->httpx->apache-airflow==2.8.1)
#   Downloading anyio-4.2.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=3.6.0->flask<2.3,>=2.2->apache-airflow==2.8.1)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/daniel/opt/anaconda3/envs/my_env_2/lib/python3.9/site-packages (from requests<3,>=2.9.1->connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1) (3.3.2)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.9.1->connexion<3.0,>=2.10.0->connexion[flask]<3.0,>=2.10.0->apache-airflow==2.8.1)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.3 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp->apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading multidict-6.0.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading yarl-1.9.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading frozenlist-1.4.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->apache-airflow-providers-http->apache-airflow==2.8.1)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx->apache-airflow==2.8.1)
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting importlib-resources>=1.3 (from limits>=2.8->Flask-Limiter<4,>3->flask-appbuilder==4.3.10->apache-airflow==2.8.1)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-sdk~=1.22.0->opentelemetry-exporter-otlp-proto-grpc==1.22.0->opentelemetry-exporter-otlp->apache-airflow==2.8.1)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Downloading apache_airflow-2.8.1-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading Flask_AppBuilder-4.3.10-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.8 MB/s eta 0:00:0000:0100:01
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 12.3 MB/s eta 0:00:00
# Downloading argcomplete-3.2.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.1 MB/s eta 0:00:00
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading colorlog-4.8.0-py2.py3-none-any.whl (10 kB)
# Downloading ConfigUpdater-3.2-py2.py3-none-any.whl (34 kB)
# Downloading connexion-2.14.2-py2.py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 9.2 MB/s eta 0:00:00
# Downloading croniter-2.0.1-py2.py3-none-any.whl (19 kB)
# Downloading cryptography-41.0.7-cp37-abi3-macosx_10_12_universal2.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 12.2 MB/s eta 0:00:0000:0100:01
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.6 MB/s eta 0:00:00
# Downloading Flask_Caching-2.1.0-py3-none-any.whl (28 kB)
# Downloading Flask_Login-0.6.3-py3-none-any.whl (17 kB)
# Downloading flask_session-0.5.0-py3-none-any.whl (7.2 kB)
# Downloading flask_wtf-1.2.1-py3-none-any.whl (12 kB)
# Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 8.4 MB/s eta 0:00:00
# Downloading google_re2-1.1-6-cp39-cp39-macosx_14_0_arm64.whl (428 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.1/428.1 kB 7.5 MB/s eta 0:00:00a 0:00:01
# Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 6.5 MB/s eta 0:00:00
# Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 7.2 MB/s eta 0:00:00
# Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Downloading lockfile-0.12.2-py2.py3-none-any.whl (13 kB)
# Downloading Markdown-3.5.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 kB 6.6 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.1 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_universal2.whl (17 kB)
# Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 5.9 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.1 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.7 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pendulum-3.0.0-cp39-cp39-macosx_11_0_arm64.whl (353 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.3/353.3 kB 10.3 MB/s eta 0:00:00
# Downloading pluggy-1.3.0-py3-none-any.whl (18 kB)
# Downloading psutil-5.9.7-cp38-abi3-macosx_11_0_arm64.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 kB 5.2 MB/s eta 0:00:0000:01
# Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 8.7 MB/s eta 0:00:00:00:01
# Downloading pydantic_core-2.14.6-cp39-cp39-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.0 MB/s eta 0:00:00a 0:00:01m
# Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Downloading python_daemon-3.0.1-py3-none-any.whl (31 kB)
# Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 10.1 MB/s eta 0:00:00
# Downloading python_slugify-8.0.1-py2.py3-none-any.whl (9.7 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 10.8 MB/s eta 0:00:00
# Downloading rich_argparse-1.4.0-py3-none-any.whl (19 kB)
# Downloading setproctitle-1.3.3-cp39-cp39-macosx_10_9_universal2.whl (16 kB)
# Downloading SQLAlchemy_JSONField-1.0.2-py3-none-any.whl (10 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading universal_pathlib-0.1.4-py3-none-any.whl (20 kB)
# Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 9.4 MB/s eta 0:00:00
# Downloading apache_airflow_providers_common_io-1.2.0-py3-none-any.whl (12 kB)
# Downloading apache_airflow_providers_common_sql-1.10.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.5 MB/s eta 0:00:00
# Downloading apache_airflow_providers_ftp-3.7.0-py3-none-any.whl (19 kB)
# Downloading apache_airflow_providers_http-4.8.0-py3-none-any.whl (25 kB)
# Downloading apache_airflow_providers_imap-3.5.0-py3-none-any.whl (17 kB)
# Downloading apache_airflow_providers_sqlite-3.7.0-py3-none-any.whl (13 kB)
# Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 7.3 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp-1.22.0-py3-none-any.whl (7.0 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.22.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 4.9 MB/s eta 0:00:00
# Downloading apispec-6.4.0-py3-none-any.whl (30 kB)
# Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Using cached cffi-1.16.0-cp39-cp39-macosx_11_0_arm64.whl (176 kB)
# Downloading clickclick-20.10.2-py2.py3-none-any.whl (7.4 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading email_validator-1.3.1-py2.py3-none-any.whl (22 kB)
# Downloading Flask_Babel-2.0.0-py3-none-any.whl (9.3 kB)
# Downloading Flask_JWT_Extended-4.6.0-py2.py3-none-any.whl (22 kB)
# Downloading Flask_Limiter-3.5.0-py3-none-any.whl (28 kB)
# Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 6.2 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading marshmallow-3.20.2-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.0 MB/s eta 0:00:00
# Downloading marshmallow_sqlalchemy-0.26.1-py2.py3-none-any.whl (15 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading prison-0.2.1-py2.py3-none-any.whl (5.8 kB)
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 13.0 MB/s eta 0:00:0000:01
# Downloading referencing-0.32.1-py3-none-any.whl (26 kB)
# Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 9.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading rpds_py-0.17.1-cp39-cp39-macosx_11_0_arm64.whl (353 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.4/353.4 kB 10.5 MB/s eta 0:00:00
# Downloading SQLAlchemy_Utils-0.41.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 7.7 MB/s eta 0:00:00
# Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.7 MB/s eta 0:00:00
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 6.8 MB/s eta 0:00:00
# Downloading time_machine-2.13.0-cp39-cp39-macosx_10_9_universal2.whl (20 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 12.9 MB/s eta 0:00:00
# Downloading wrapt-1.16.0-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Downloading wtforms-3.1.2-py3-none-any.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 8.7 MB/s eta 0:00:00
# Downloading aiohttp-3.9.1-cp39-cp39-macosx_11_0_arm64.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.3/387.3 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 11.4 MB/s eta 0:00:00a 0:00:01
# Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.3 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.3 MB/s eta 0:00:00
# Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading anyio-4.2.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 7.0 MB/s eta 0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached Babel-2.14.0-py3-none-any.whl (11.0 MB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached dnspython-2.4.2-py3-none-any.whl (300 kB)
# Downloading frozenlist-1.4.1-cp39-cp39-macosx_11_0_arm64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.9 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading grpcio-1.60.0-cp39-cp39-macosx_10_10_universal2.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 2.9 MB/s eta 0:00:0000:0100:01m
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.4 MB/s eta 0:00:00
# Downloading limits-3.7.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 3.9 MB/s eta 0:00:00
# Downloading multidict-6.0.4-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 8.1 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 9.3 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp39-cp39-macosx_11_0_arm64.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 6.1 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 7.1 MB/s eta 0:00:00
# Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading protobuf-4.25.2-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 10.7 MB/s eta 0:00:00
# Building wheels for collected packages: cron-descriptor, dill, python-nvd3, sqlalchemy, unicodecsv, lazy-object-proxy
#   Building wheel for cron-descriptor (setup.py) ... done
#   Created wheel for cron-descriptor: filename=cron_descriptor-1.4.0-py3-none-any.whl size=49837 sha256=81922b7ea00abf72b9a6aa7fe66bd4dfd7b48cfa973daf0197bbae30cd6b4f0a
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/91/41/27/d4b453bad5dec735b7572d4c5b064371ea66be40c042857e3a
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78542 sha256=a2fe144e33b4f292c8988a890e6892cb32646426518a52ac680a540fadfb1c52
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/4f/0b/ce/75d96dd714b15e51cb66db631183ea3844e0c4a6d19741a149
#   Building wheel for python-nvd3 (setup.py) ... done
#   Created wheel for python-nvd3: filename=python_nvd3-0.15.0-py3-none-any.whl size=38145 sha256=dd57cd99817637090ba83c2ecd859a5909d2cbeac3405f6b3dd2a234960b3b31
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/60/e8/21/19a3dcfe90e8895952857d42152663fafc5a90d87d3dfe5f58
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.4.51-cp39-cp39-macosx_11_0_arm64.whl size=1571653 sha256=b9ab336ef8ae65355e12fb6075d4941862e27ab6ab46e60eb416e8cd9101c171
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/ea/1f/c4/709e5d2dadd5fcf063a6eab07bee8692056f8699367111f2b0
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10747 sha256=7e9a18d8458433c3321d03e040337a838655ecc8281fd3562061d04a8e256f7f
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/d8/c8/27/b237d3378d5c9ed25c2c63d9af1b3d5ccb99934f3dd030de87
#   Building wheel for lazy-object-proxy (pyproject.toml) ... done
#   Created wheel for lazy-object-proxy: filename=lazy_object_proxy-1.10.0-cp39-cp39-macosx_11_0_arm64.whl size=25551 sha256=67429f14f3485ac7c45c84a0b24c591f2670ba491e397e581eb300207d17bbb4
#   Stored in directory: /Users/daniel/Library/Caches/pip/wheels/72/81/44/1c731d4e3964cfd08c5136901f1d4d84aca19e320b9860bc60
# Successfully built cron-descriptor dill python-nvd3 sqlalchemy unicodecsv lazy-object-proxy
# Installing collected packages: unicodecsv, text-unidecode, rfc3986, pytz, lockfile, cron-descriptor, colorlog, zipp, wrapt, urllib3, uc-micro-py, tzdata, typing-extensions, termcolor, tenacity, tabulate, sqlparse, sqlalchemy, setproctitle, rpds-py, rfc3339-validator, python-slugify, python-dateutil, pyjwt, pycparser, psutil, protobuf, prison, pluggy, pathspec, packaging, opentelemetry-semantic-conventions, multidict, mdurl, markupsafe, lazy-object-proxy, itsdangerous, inflection, idna, grpcio, google-re2, fsspec, frozenlist, exceptiongroup, docutils, dnspython, dill, configupdater, colorama, clickclick, certifi, cachelib, blinker, backoff, Babel, attrs, async-timeout, argcomplete, yarl, WTForms, werkzeug, universal-pathlib, time-machine, sqlalchemy-utils, sqlalchemy-jsonfield, referencing, python-daemon, pydantic-core, opentelemetry-proto, marshmallow, markdown-it-py, Mako, linkify-it-py, importlib-resources, importlib-metadata, gunicorn, googleapis-common-protos, email-validator, deprecated, croniter, cffi, asgiref, apispec, anyio, aiosignal, rich, requests_toolbelt, python-nvd3, pydantic, pendulum, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, mdit-py-plugins, marshmallow-sqlalchemy, marshmallow-oneofschema, markdown, limits, jsonschema-specifications, httpcore, flask, cryptography, alembic, aiohttp, rich-argparse, opentelemetry-sdk, jsonschema, httpx, flask-wtf, Flask-SQLAlchemy, flask-session, flask-login, Flask-Limiter, Flask-JWT-Extended, flask-caching, Flask-Babel, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, flask-appbuilder, connexion, opentelemetry-exporter-otlp, apache-airflow-providers-common-sql, apache-airflow-providers-sqlite, apache-airflow-providers-imap, apache-airflow-providers-http, apache-airflow-providers-ftp, apache-airflow-providers-common-io, apache-airflow
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: sqlparse
#     Found existing installation: sqlparse 0.5.3
#     Uninstalling sqlparse-0.5.3:
#       Successfully uninstalled sqlparse-0.5.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.41
#     Uninstalling SQLAlchemy-2.0.41:
#       Successfully uninstalled SQLAlchemy-2.0.41
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.25.0
#     Uninstalling rpds-py-0.25.0:
#       Successfully uninstalled rpds-py-0.25.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0
#     Uninstalling python-dateutil-2.9.0:
#       Successfully uninstalled python-dateutil-2.9.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.0
#     Uninstalling protobuf-6.31.0:
#       Successfully uninstalled protobuf-6.31.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.54b1
#     Uninstalling opentelemetry-semantic-conventions-0.54b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.54b1
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 2.2.0
#     Uninstalling itsdangerous-2.2.0:
#       Successfully uninstalled itsdangerous-2.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.3.1
#     Uninstalling fsspec-2024.3.1:
#       Successfully uninstalled fsspec-2024.3.1
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.1.3
#     Uninstalling exceptiongroup-1.1.3:
#       Successfully uninstalled exceptiongroup-1.1.3
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 2.6.1
#     Uninstalling dnspython-2.6.1:
#       Successfully uninstalled dnspython-2.6.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.9.0
#     Uninstalling blinker-1.9.0:
#       Successfully uninstalled blinker-1.9.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.0.6
#     Uninstalling Werkzeug-3.0.6:
#       Successfully uninstalled Werkzeug-3.0.6
#   Attempting uninstall: referencing
#     Found existing installation: referencing 0.36.2
#     Uninstalling referencing-0.36.2:
#       Successfully uninstalled referencing-0.36.2
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.10.1
#     Uninstalling pydantic_core-2.10.1:
#       Successfully uninstalled pydantic_core-2.10.1
#   Attempting uninstall: Mako
#     Found existing installation: Mako 1.3.10
#     Uninstalling Mako-1.3.10:
#       Successfully uninstalled Mako-1.3.10
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib_resources 6.4.0
#     Uninstalling importlib_resources-6.4.0:
#       Successfully uninstalled importlib_resources-6.4.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: gunicorn
#     Found existing installation: gunicorn 23.0.0
#     Uninstalling gunicorn-23.0.0:
#       Successfully uninstalled gunicorn-23.0.0
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.18
#     Uninstalling Deprecated-1.2.18:
#       Successfully uninstalled Deprecated-1.2.18
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.4.2
#     Uninstalling pydantic-2.4.2:
#       Successfully uninstalled pydantic-2.4.2
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.33.1
#     Uninstalling opentelemetry-api-1.33.1:
#       Successfully uninstalled opentelemetry-api-1.33.1
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.8
#     Uninstalling Markdown-3.8:
#       Successfully uninstalled Markdown-3.8
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2025.4.1
#     Uninstalling jsonschema-specifications-2025.4.1:
#       Successfully uninstalled jsonschema-specifications-2025.4.1
#   Attempting uninstall: flask
#     Found existing installation: Flask 3.0.3
#     Uninstalling Flask-3.0.3:
#       Successfully uninstalled Flask-3.0.3
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.16.1
#     Uninstalling alembic-1.16.1:
#       Successfully uninstalled alembic-1.16.1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.33.1
#     Uninstalling opentelemetry-sdk-1.33.1:
#       Successfully uninstalled opentelemetry-sdk-1.33.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi 0.104.1 requires anyio<4.0.0,>=3.7.1, but you have anyio 4.2.0 which is incompatible.
# Successfully installed Babel-2.14.0 Flask-Babel-2.0.0 Flask-JWT-Extended-4.6.0 Flask-Limiter-3.5.0 Flask-SQLAlchemy-2.5.1 Mako-1.3.0 WTForms-3.1.2 aiohttp-3.9.1 aiosignal-1.3.1 alembic-1.13.1 anyio-4.2.0 apache-airflow-2.8.1 apache-airflow-providers-common-io-1.2.0 apache-airflow-providers-common-sql-1.10.0 apache-airflow-providers-ftp-3.7.0 apache-airflow-providers-http-4.8.0 apache-airflow-providers-imap-3.5.0 apache-airflow-providers-sqlite-3.7.0 apispec-6.4.0 argcomplete-3.2.1 asgiref-3.7.2 async-timeout-4.0.3 attrs-23.2.0 backoff-2.2.1 blinker-1.7.0 cachelib-0.9.0 certifi-2023.11.17 cffi-1.16.0 clickclick-20.10.2 colorama-0.4.6 colorlog-4.8.0 configupdater-3.2 connexion-2.14.2 cron-descriptor-1.4.0 croniter-2.0.1 cryptography-41.0.7 deprecated-1.2.14 dill-0.3.1.1 dnspython-2.4.2 docutils-0.20.1 email-validator-1.3.1 exceptiongroup-1.2.0 flask-2.2.5 flask-appbuilder-4.3.10 flask-caching-2.1.0 flask-login-0.6.3 flask-session-0.5.0 flask-wtf-1.2.1 frozenlist-1.4.1 fsspec-2023.12.2 google-re2-1.1 googleapis-common-protos-1.62.0 grpcio-1.60.0 gunicorn-21.2.0 httpcore-0.16.3 httpx-0.23.3 idna-3.6 importlib-metadata-6.11.0 importlib-resources-6.1.1 inflection-0.5.1 itsdangerous-2.1.2 jsonschema-4.20.0 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 limits-3.7.0 linkify-it-py-2.0.2 lockfile-0.12.2 markdown-3.5.2 markdown-it-py-3.0.0 markupsafe-2.1.3 marshmallow-3.20.2 marshmallow-oneofschema-3.0.1 marshmallow-sqlalchemy-0.26.1 mdit-py-plugins-0.4.0 mdurl-0.1.2 multidict-6.0.4 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-exporter-otlp-proto-http-1.22.0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 packaging-23.2 pathspec-0.12.1 pendulum-3.0.0 pluggy-1.3.0 prison-0.2.1 protobuf-4.25.2 psutil-5.9.7 pycparser-2.21 pydantic-2.5.3 pydantic-core-2.14.6 pyjwt-2.8.0 python-daemon-3.0.1 python-dateutil-2.8.2 python-nvd3-0.15.0 python-slugify-8.0.1 pytz-2023.3.post1 referencing-0.32.1 requests_toolbelt-1.0.0 rfc3339-validator-0.1.4 rfc3986-1.5.0 rich-13.7.0 rich-argparse-1.4.0 rpds-py-0.17.1 setproctitle-1.3.3 sqlalchemy-1.4.51 sqlalchemy-jsonfield-1.0.2 sqlalchemy-utils-0.41.1 sqlparse-0.4.4 tabulate-0.9.0 tenacity-8.2.3 termcolor-2.4.0 text-unidecode-1.3 time-machine-2.13.0 typing-extensions-4.8.0 tzdata-2023.4 uc-micro-py-1.0.2 unicodecsv-0.14.1 universal-pathlib-0.1.4 urllib3-1.26.18 werkzeug-2.2.3 wrapt-1.16.0 yarl-1.9.4 zipp-3.17.0

# %% [markdown]
# ## Q2

# %%
#q2
# !airflow version
# Out:
# 2.8.1
